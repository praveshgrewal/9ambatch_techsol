# %%
# type conversion

# %%
'12' + 12
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 '12' + 12
#
# TypeError: can only concatenate str (not "int") to str

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
num = 12

num2 = 34.7
output = num+num2
print(output)
print(type(output))
# Out:
# 46.7
# <class 'float'>

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
num3 = '23'
print(type(num3))
num4 = bool(num3)
print(num4)
print(type(num4))
# Out:
# <class 'str'>
# True
# <class 'bool'>

# %%
# 1 ---> True
# 0 --- >False

# %%
bool('@')
# Out:
# True

# %% [markdown]
# ### input ---> by default string

# %%
num10 = int(input('Enter 1st Number: '))

num11 = int(input('Enter 2nd Number: '))
output = num10 + num11

print(output)
# Out:
# 32

# %%
# 3 user se input and multiply
