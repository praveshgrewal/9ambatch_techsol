# %%
name = 'sajid khan'
print(name)
print(type(name))
# Out:
# sajid khan
# <class 'str'>

# %%
print(name.capitalize())
# Out:
# Sajid khan

# %%
print(name.title())
# Out:
# Sajid Khan

# %%
print(name.upper())
# Out:
# SAJID KHAN

# %%
print(name.lower())
# Out:
# sajid khan

# %%
print(name.casefold())
# Out:
# sajid khan

# %%
print(name.center(30,'-'))
print(name.ljust(30,'-'))
print(name.rjust(30,'-'))
# Out:
# ----------sajid khan----------
# sajid khan--------------------
# --------------------sajid khan

# %%
len(name)
# Out:
# 10

# %%
max(name)
# Out:
# 's'

# %%
min(name)
# Out:
# ' '

# %%
text = "sajidkhan"
min(text)
# Out:
# 'a'

# %%
text.count('n')
# Out:
# 1

# %%
print('a' in text)
# Out:
# True

# %%
text
# Out:
# 'sajidkhan'

# %% [markdown]
# ### indexing

# %%
print(text.find('A'))
print(text.rfind('a'))
# Out:
# -1
# 7

# %%
print(text.index('A'))
print(text.rindex('a'))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[39], line 1
# ----> 1 print(text.index('A'))
#       2 print(text.rindex('a'))
#
# ValueError: substring not found

# %% [markdown]
# ### slicing

# %%
text
# Out:
# 'sajidkhan'

# %%
text[5]
# Out:
# 'k'

# %%
text
# Out:
# 'sajidkhan'

# %%
text[5:9] # text[stat:end:step]
# Out:
# 'khan'

# %%
text2 = "i love python programming"

# %%
len(text2)
# Out:
# 25

# %%
print(text2.rfind('p'))
print(text2.find('n'))
# Out:
# 14
# 12

# %%
text2[::-1]
# Out:
# 'gnimmargorp nohtyp evol i'

# %%
text2[-25:-19]
# Out:
# 'i love'

# %%
name
# Out:
# 'sajid khan'

# %%
name[::-1]
# Out:
# 'nahk dijas'
