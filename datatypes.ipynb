# %% [markdown]
# ### int --> number

# %%
num = 12
print(num)
print(type(num)) # to check the type of data
# Out:
# 12
# <class 'int'>

# %%
print(type(123))
# Out:
# <class 'int'>

# %% [markdown]
# ### string(str)---> text

# %%
first = "123"
print(first)
print(type(first))
# Out:
# 123
# <class 'str'>

# %% [markdown]
# #### python is a dynamically type progrmming language

# %%
sec = 'khan'
print(sec)
print(type(sec))
# Out:
# khan
# <class 'str'>

# %%
thired = """okhla vihar"""
print(thired)
print(type(thired))
# Out:
# okhla vihar
# <class 'str'>

# %%
forth = '''india 110025'''
print(forth)
print(type(forth))
# Out:
# india 110025
# <class 'str'>

# %%
# my name is "sajid"
print('''my name is 'sajid' ''')
# Out:
# my name is 'sajid'

# %% [markdown]
# ### decimal ---> float

# %%
salary = 23.68967
print(salary)
print(type(salary))
# Out:
# 23.68967
# <class 'float'>

# %% [markdown]
# ### boolean(bool)---> True/False

# %%
f= False
print(f)
print(type(f))
t = True
print(t)
print(type(t))
# Out:
# False
# <class 'bool'>
# True
# <class 'bool'>

# %% [markdown]
# ### None ---> NoneType (nothing)

# %%
no =None
print(no)
print(type(no))
# Out:
# None
# <class 'NoneType'>

# %% [markdown]
# ### complex ---> real _ im

# %%
com = 3+5j
print(com)
print(type(com))
# Out:
# (3+5j)
# <class 'complex'>

# %% [markdown]
# ### list ---> [ ]

# %%
my_list = [1,2,3,'sajid',34.8,True]
print(my_list)
print(type(my_list))
# Out:
# [1, 2, 3, 'sajid', 34.8, True]
# <class 'list'>

# %%
num2 = [1,2,3,6,9,2,5,9]
print(num2)
# Out:
# [1, 2, 3, 6, 9, 2, 5, 9]

# %% [markdown]
# ### tuple ---> ( )

# %%
my_tuple = (1,2,3,'sajid',34.8,True)
print(my_tuple)
print(type(my_tuple))
# Out:
# (1, 2, 3, 'sajid', 34.8, True)
# <class 'tuple'>

# %% [markdown]
# ### set ---> { }

# %%
my_set = {1,2,3,'sajid',34.8,True}
print(my_set)
print(type(my_set))
# Out:
# {1, 2, 3, 34.8, 'sajid'}
# <class 'set'>

# %% [markdown]
# ### dictionary --- >dict ( 'key':'value')

# %%
my_dict = {'name':'amaan','age':27}
print(my_dict)
print(type(my_dict))
# Out:
# {'name': 'amaan', 'age': 27}
# <class 'dict'>
