# %%
name = "sajid khan"
print(name)
# Out:
# sajid khan

# %% [markdown]
# #### memory location ---> id( )

# %%
name2 = "amaan"
print(name2)
print(id(name2))
# Out:
# amaan
# 4469874224

# %%
age = 27
print(age)
print(id(age))
# Out:
# 27
# 4358384888

# %% [markdown]
# #### if the values are same memory location will be same
# * prevent memory wastage

# %%
score = 27
print(id(score))
# Out:
# 4358384888

# %% [markdown]
# #### python will store values in memory location not variables

# %% [markdown]
# ## rules and regulation of variables

# %%
# can't start from a number
10 = "amaan"
# Out:
#   Cell In[6], line 2
#     10 = "amaan"
#     ^
# SyntaxError: cannot assign to literal here. Maybe you meant '==' instead of '='?

# %%
# can't use special char and space
name@stu = "sajid"
# Out:
#   Cell In[7], line 2
#     name@stu = "sajid"
#     ^
# SyntaxError: cannot assign to expression here. Maybe you meant '==' instead of '='?

# %%
# python is a case senstive programming lang

# %%
Student_name = "sajid"
print(student_name)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 2
#       1 Student_name = "sajid"
# ----> 2 print(student_name)
#
# NameError: name 'student_name' is not defined

# %%
# can't be a keyword(reserve words in python)
if = "sajid"
# Out:
#   Cell In[11], line 2
#     if = "sajid"
#        ^
# SyntaxError: invalid syntax

# %%
import keyword
print(keyword.kwlist)
# Out:
# ['False', 'None', 'True', 'and', 'as', 'assert', 'async', 'await', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']

# %%
name23 = "sajid"

# %% [markdown]
# #### python prefer snake case (name_of_studnet) insted of the camel case(StuDRT)

# %%
# comments --- >notes in programm file (# )

# %%
# we don't have multi line comments in python

# %%
"""this is multi line comment in python(jugaad)"""
print("this is test")
# Out:
# this is test

# %% [markdown]
# #### ctrl + / ( for multi line comments in VSCode) make sure limited to some IDE only this is not function of python

# %%
a,b,c = 1,2,3
print(a)
print(b)
print(c)
# Out:
# 1
# 2
# 3

# %%
x=y=z=12
print(x)
print(y)
print(z)
# Out:
# 12
# 12
# 12
