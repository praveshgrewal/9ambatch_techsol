# %% [markdown]
# ## Conditional Statements:

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
age = int(input('Enter Your age: '))
if age > 18:
    print(f"your age is {age} & your are eligible for voting")
else:
    print(age,": abhi tu bacha hai!")
# Out:
# your age is 23 & your are eligible for voting

# %% [markdown]
# ### f-string

# %%
name = "sajid"
age = 23
print("my name is",name,"i am ",age,"years old")
# Out:
# my name is sajid i am  23 years old

# %%
print(f"my name is {name} and i am {age} years old")
# Out:
# my name is sajid and i am 23 years old

# %%
score = 340
result = "pass" if score >= 50 else "fail"
print(result)
# Out:
# pass

# %% [markdown]
# ### if else elif

# %%
# marks = 120
# if marks > 100:
#     print("check number again")
#     exit()

# if marks >= 90:
#     grade = "A"
# elif marks >= 75:
#     grade = "B"
# elif marks >= 50:
#     grade = "C"
# else:
#     grade = "Fail"
# print(grade)

# %% [markdown]
# ### nested if else

# %%
### age > 18 , credit score = 900 + credit card

# %%
age = 2
credit_score = 890
if age > 18:
    if credit_score > 900:
        print("you are eligible for credit card")
    else:
        print("please improve your credit score first!")
else:
    print("abhi tu bacha hai!")
# Out:
# abhi tu bacha hai!

# %%
age = 2
credit_score = 890

if age > 18 and credit_score > 900:
    print("you can go")
else:
    print('not eligible')
# Out:
# not eligible
